# %%
import pandas as pd 

df = pd.read_excel("imoveis_aquisicoes_brasil.xlsx")

df
# Out:
#                   logradouro tipo_logradouro            bairro  \
# 0              Quinta do Sol             Rua  Alto da Pedreira
# 1           Antonio Loureiro             Rua  Alto da Pedreira
# 2     Canario Branco Central             Rua  Alto da Pedreira
# 3              das Palmeiras         Avenida  Alto da Pedreira
# 4           Antonio Loureiro             Rua  Alto da Pedreira
# ...                      ...             ...               ...
# 1495         Veredas do Lago             Rua    Vila Primavera
# 1496                dos Ipes         Estrada    Vila Primavera
# 1497         Benedito Campos             Rua    Vila Primavera
# 1498              Joao Marin             Rua    Vila Primavera
# 1499             Monte Claro        Travessa    Vila Primavera
#
#               cidade       cep       tipo      valor data_aquisicao
# 0     Belo Horizonte  30840439    Terreno  1192500.0     2015-10-10
# 1     Belo Horizonte  30026486       Casa  1127500.0     2016-12-02
# ...

# %%
# nesse caso o len mostra a quatidade de linhas 

print(len(df))
# Out:
# 1500

# %%
# aqui o len já mostra a quantidade de colunas 
print(len(df.columns))
# Out:
# 8

# %%
# b) Quantas colunas numéricas o dataset possui?
# lembrando que o dataset é o conjunto de dados que estão na minha tabela  e o projeto é a pasta
# que tem essa tabela mas também tem o notebook (.ipynb) com o código, o ambiente virtual Venv, 
# as bibliotecas  e etc...

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   logradouro       1500 non-null   str
#  1   tipo_logradouro  1500 non-null   str
#  2   bairro           1500 non-null   str
#  3   cidade           1500 non-null   str
#  4   cep              1500 non-null   int64
#  5   tipo             1500 non-null   str
#  6   valor            1500 non-null   float64
#  7   data_aquisicao   1500 non-null   datetime64[us]
# dtypes: datetime64[us](1), float64(1), int64(1), str(5)
# memory usage: 93.9 KB

# %%
# b) Quantas colunas numéricas o dataset possui?
# já nesse caso  ele mostra já calculado a quantidade de colunas por tipo. 
# df.dtypes = lista o tipo de cada coluna 
# .value_counts()  conta quantas colunas tem por esses tipos que eu listei no df.dtypes

df.dtypes.value_counts()
# Out:
# str               5
# int64             1
# float64           1
# datetime64[us]    1
# Name: count, dtype: int64

# %%
# d) Escreva o endereço completo do imóvel com o menor valor 
# esse sort_values  ordena os valores do menor para o maior 

df.sort_values("valor")
# Out:
#                    logradouro tipo_logradouro                      bairro  \
# 903                Joao Marin         Estrada         Parque das Aroeiras
# 523            das Cerejeiras             Rua           Vila Lagoa Serena
# 928                  dos Ipes        Travessa       Vila Santa Clara Alta
# 135                 Paineiras         Estrada        Vila Ouro Preto Nova
# 569   Veredas do Lago Central             Rua  Residencial Anhanguera Sul
# ...                       ...             ...                         ...
# 189            Clara Nogueira         Alameda          Jardim Cambui Novo
# 606           Olivia Monteiro           Praca          Campo Oceano Verde
# 1326               Morro Azul             Rua          Jardim Laranjeiras
# 1264             Campo Sereno             Rua    Residencial Aquarius Sul
# 328                Joao Marin         Avenida         Parque Barigui Novo
#
#                    cidade       cep    tipo      valor data_aquisicao
# ...

# %%
# d) Escreva o endereço completo do imóvel com o maior valor 
# esse sort_values (coluna , ascending=False) ordena os valores do maior para o menor. 

df.sort_values("valor" , ascending=False)
# Out:
#                    logradouro tipo_logradouro                      bairro  \
# 328                Joao Marin         Avenida         Parque Barigui Novo
# 1264             Campo Sereno             Rua    Residencial Aquarius Sul
# 1326               Morro Azul             Rua          Jardim Laranjeiras
# 606           Olivia Monteiro           Praca          Campo Oceano Verde
# 189            Clara Nogueira         Alameda          Jardim Cambui Novo
# ...                       ...             ...                         ...
# 569   Veredas do Lago Central             Rua  Residencial Anhanguera Sul
# 135                 Paineiras         Estrada        Vila Ouro Preto Nova
# 928                  dos Ipes        Travessa       Vila Santa Clara Alta
# 903                Joao Marin         Estrada         Parque das Aroeiras
# 523            das Cerejeiras             Rua           Vila Lagoa Serena
#
#                    cidade       cep    tipo      valor data_aquisicao
# ...

# %%
# Calcule a soma dos valores de todos os imóveis da tabela
# quando vou acessar uma coluna é sempre [] e quando vou chamar uma função  é sempre  ()
# [] = pegar/filtrar dados
# () = executar algo (função/método)

df['valor'].sum()
# Out:
# np.float64(1316455000.0)

# %%
# Calcule a soma dos valores de todos os imóveis da tabela
soma = df["valor"].sum()

print(f"A soma dos valores dos imóveis é de R$ {soma}")
# Out:
# A soma dos valores dos imóveis é de R$ 1316455000.0

# %%
# Calcule a soma dos valores de todos os imóveis da tabela
# aqui usei o print de um jeito diferente , somei string com a variável soma  
# mas o que está dentro dessa variável tem que ser string também , por  isso usei o str

soma = str(df['valor'].sum())
print("A soma dos valores dos imóveis é de R$ " + soma)
# Out:
# A soma dos valores dos imóveis é de R$ 1316455000.0

# %%
# Calcule a média dos valores de todos os imóveis da tabela

df['valor'].mean()
# Out:
# np.float64(877636.6666666666)

# %%
# Calcule a média dos valores de todos os imóveis da tabela

media= df['valor'].mean()

print(f"A média dos valores dos imóveis é de R$ {media}")
# Out:
# A média dos valores dos imóveis é de R$ 877636.6666666666

# %%
# Calcule a mediana dos valores de todos os imóveis da tabela

df['valor'].median()
# Out:
# np.float64(712500.0)

# %%
# Calcule a mediana dos valores de todos os imóveis da tabela

mediana = df['valor'].median()

print(f"A mediana dos valores dos imóveis é de R$ {mediana}")
# Out:
# A mediana dos valores dos imóveis é de R$ 712500.0

# %%
# Calcule o desvio padrão dos valores de todos os imóveis da tabela


df['valor'].std()
# Out:
# np.float64(646676.0007057745)

# %%
# Calcule o desvio padrão dos valores de todos os imóveis da tabela

desvio_padrao = df["valor"].std()

print(f"O desvio padrão dos imóveis é de {desvio_padrao}")
# Out:
# O desvio padrão dos imóveis é de 646676.0007057745

# %%
# Exiba apenas os imóveis da cidade "Curitiba"
# desse jeito eu não criei variável. Mas no próximo vou criá-la 
 
df[df["cidade"] == "Curitiba"]
# Out:
#                logradouro tipo_logradouro          bairro    cidade       cep  \
# 250      Vale Verde Oeste         Alameda   Alto Capivari  Curitiba  82120169
# 251         Padre Avelino         Avenida   Alto Capivari  Curitiba  82754280
# 252           das Acacias             Rua   Alto Capivari  Curitiba  80251237
# 253          Campo Sereno             Rua   Alto Capivari  Curitiba  82695448
# 254         Quinta do Sol             Rua   Alto Capivari  Curitiba  80387186
# ..                    ...             ...             ...       ...       ...
# 360          Serra Bonita         Alameda  Vila Pinheiros  Curitiba  81457564
# 361        Canario Branco             Rua  Vila Pinheiros  Curitiba  80817291
# 362       Olivia Monteiro         Rodovia  Vila Pinheiros  Curitiba  80192125
# 363  Ribeirao Claro Oeste         Avenida  Vila Pinheiros  Curitiba  81222033
# 364    Engenheiro Tavares             Rua  Vila Pinheiros  Curitiba  82433117
#
# ...

# %%
# Exiba apenas os imóveis da cidade "Curitiba"

df_Curitiba = df[df["cidade"] == "Curitiba"]


df_Curitiba
# Out:
#                logradouro tipo_logradouro          bairro    cidade       cep  \
# 250      Vale Verde Oeste         Alameda   Alto Capivari  Curitiba  82120169
# 251         Padre Avelino         Avenida   Alto Capivari  Curitiba  82754280
# 252           das Acacias             Rua   Alto Capivari  Curitiba  80251237
# 253          Campo Sereno             Rua   Alto Capivari  Curitiba  82695448
# 254         Quinta do Sol             Rua   Alto Capivari  Curitiba  80387186
# ..                    ...             ...             ...       ...       ...
# 360          Serra Bonita         Alameda  Vila Pinheiros  Curitiba  81457564
# 361        Canario Branco             Rua  Vila Pinheiros  Curitiba  80817291
# 362       Olivia Monteiro         Rodovia  Vila Pinheiros  Curitiba  80192125
# 363  Ribeirao Claro Oeste         Avenida  Vila Pinheiros  Curitiba  81222033
# 364    Engenheiro Tavares             Rua  Vila Pinheiros  Curitiba  82433117
#
# ...

# %%
# Nesse caso , ele puxou Niteroi porque eu usei o DF original , se eu tivesse usado o df_Curitiba   == Niteroi não teria vindo nada  

df_Curitiba = df[df["cidade"] == "Niteroi"]

df_Curitiba
# Out:
#                  logradouro tipo_logradouro                     bairro  \
# 597          dos Jacarandas             Rua               Alto da Baia
# 598     Monte Claro Central           Largo               Alto da Baia
# 599      dos Jacarandas Sul           Praca               Alto da Baia
# 600             Nova Aurora             Rua               Alto da Baia
# 601        Domingos Arantes             Rua               Alto da Baia
# 602            das Violetas             Rua               Alto da Baia
# 603            Sol Nascente             Rua               Alto da Baia
# 604           Alto do Cedro             Rua         Campo Oceano Verde
# 605           das Orquideas        Travessa         Campo Oceano Verde
# 606         Olivia Monteiro           Praca         Campo Oceano Verde
# 607       Professor Almeida         Avenida         Jardim Icarai Novo
# 608            das Violetas        Travessa         Jardim Icarai Novo
# ...

# %%
# Exiba os imóveis cujo tipo seja "apartamento".
# Aqui fiz direto sem criar variável 

df[df["tipo"] == "Apartamento"]
# Out:
#                   logradouro tipo_logradouro                 bairro  \
# 9             Helena Sampaio         Alameda       Alto da Pedreira
# 11            Clara Nogueira             Rua       Alto da Pedreira
# 13                Vale Verde             Rua       Alto da Pedreira
# 14           Veredas do Lago         Avenida  Jardim Horizonte Azul
# 22               Sao Gabriel         Avenida  Jardim Horizonte Azul
# ...                      ...             ...                    ...
# 1476  Helena Sampaio Central             Rua         Vila Primavera
# 1479             Sao Gabriel         Avenida         Vila Primavera
# 1482         Veredas do Lago             Rua         Vila Primavera
# 1485            Serra Bonita             Rua         Vila Primavera
# 1493      Engenheiro Tavares             Rua         Vila Primavera
#
#               cidade       cep         tipo      valor data_aquisicao
# 9     Belo Horizonte  31649896  Apartamento   527000.0     2023-06-19
# ...

# %%
# Exiba os imóveis cujo tipo seja "apartamento".
# Aqui fiz criando variável 

df_apartamento = df[df["tipo"] == "Apartamento"]

df_apartamento
# Out:
#                   logradouro tipo_logradouro                 bairro  \
# 9             Helena Sampaio         Alameda       Alto da Pedreira
# 11            Clara Nogueira             Rua       Alto da Pedreira
# 13                Vale Verde             Rua       Alto da Pedreira
# 14           Veredas do Lago         Avenida  Jardim Horizonte Azul
# 22               Sao Gabriel         Avenida  Jardim Horizonte Azul
# ...                      ...             ...                    ...
# 1476  Helena Sampaio Central             Rua         Vila Primavera
# 1479             Sao Gabriel         Avenida         Vila Primavera
# 1482         Veredas do Lago             Rua         Vila Primavera
# 1485            Serra Bonita             Rua         Vila Primavera
# 1493      Engenheiro Tavares             Rua         Vila Primavera
#
#               cidade       cep         tipo      valor data_aquisicao
# 9     Belo Horizonte  31649896  Apartamento   527000.0     2023-06-19
# ...

# %%
# Exiba apena as coluna: logradouro
# Note que seu criar aqui com um[]  fica com o formato abaixo sem o nome da coluna  mas  se eu criar com dois [] conforme no próximo notebook fica com o nome

df["logradouro"]
# Nesse caso como não vamos usar essas duas colunas para outras coisas, só pra esse exercicio, não precisei criar
# uma variável, mas se eu fosse usar várias vezes, ai teria que usar uma variável para faciliar .
# Out:
# 0                Quinta do Sol
# 1             Antonio Loureiro
# 2       Canario Branco Central
# 3                das Palmeiras
# 4             Antonio Loureiro
#                  ...
# 1495           Veredas do Lago
# 1496                  dos Ipes
# 1497           Benedito Campos
# 1498                Joao Marin
# 1499               Monte Claro
# Name: logradouro, Length: 1500, dtype: str

# %%
# Exiba apena as coluna: logradouro
# Note que seu criar aqui com um[]  fica com o formato acima sem o nome da coluna  mas  se eu criar com dois [] conforme no próximo notebook fica com o nome

df[["logradouro"]]
# Nesse caso como não vamos usar essas duas colunas para outras coisas, só pra esse exercicio, não precisei criar
# uma variável, mas se eu fosse usar várias vezes, ai teria que usar uma variável para faciliar .
# Out:
#                   logradouro
# 0              Quinta do Sol
# 1           Antonio Loureiro
# 2     Canario Branco Central
# 3              das Palmeiras
# 4           Antonio Loureiro
# ...                      ...
# 1495         Veredas do Lago
# 1496                dos Ipes
# 1497         Benedito Campos
# 1498              Joao Marin
# 1499             Monte Claro
#
# [1500 rows x 1 columns]

# %%
# Exiba apenas as colunas: logradouro e valor dos imóveis.
# Nesse caso como não vamos usar essas duas colunas para outras coisas, só pra esse exercicio, não precisei criar
# uma variável, mas se eu fosse usar várias vezes, ai teria que usar uma variável para faciliar . 

df[["logradouro" ,"valor"]]
# Out:
#                   logradouro      valor
# 0              Quinta do Sol  1192500.0
# 1           Antonio Loureiro  1127500.0
# 2     Canario Branco Central   247000.0
# 3              das Palmeiras  2095000.0
# 4           Antonio Loureiro  1392500.0
# ...                      ...        ...
# 1495         Veredas do Lago  1132500.0
# 1496                dos Ipes  1700000.0
# 1497         Benedito Campos   757500.0
# 1498              Joao Marin  2205000.0
# 1499             Monte Claro   279000.0
#
# [1500 rows x 2 columns]

# %%
# Exiba os imóveis com valor maior que 900000.
# Nesse caso se eu usar "" nos 900000 ele converte esse número em string e da erro. Número é sempre sem aspas. 
# normalmente no pandas não usamos o print , o print é mais usado na lógica de programação . 
# Mesmo esquema , aqui temos um df filtrado . Se eu quiser ficar usando ele o ideal é guardar em uma variável. 


df[df["valor"] > 900000]
# Out:
#               logradouro tipo_logradouro            bairro          cidade  \
# 0          Quinta do Sol             Rua  Alto da Pedreira  Belo Horizonte
# 1       Antonio Loureiro             Rua  Alto da Pedreira  Belo Horizonte
# 3          das Palmeiras         Avenida  Alto da Pedreira  Belo Horizonte
# 4       Antonio Loureiro             Rua  Alto da Pedreira  Belo Horizonte
# 6         Morro Azul Sul             Rua  Alto da Pedreira  Belo Horizonte
# ...                  ...             ...               ...             ...
# 1492        Laura Amaral         Rodovia    Vila Primavera       Sao Paulo
# 1493  Engenheiro Tavares             Rua    Vila Primavera       Sao Paulo
# 1495     Veredas do Lago             Rua    Vila Primavera       Sao Paulo
# 1496            dos Ipes         Estrada    Vila Primavera       Sao Paulo
# 1498          Joao Marin             Rua    Vila Primavera       Sao Paulo
#
#            cep         tipo      valor data_aquisicao
# ...

# %%
# Exiba a média de valores dos imóveis da cidade "Belo Horizonte".
# Aqui eu criei duas variáveis , no note abaixo vou fazer criando uma variável só 

df_BH = df[df["cidade"] == "Belo Horizonte"]

df_media_valor_BH =  df_BH["valor"].mean()

df_media_valor_BH
# Out:
# np.float64(771758.3892617449)

# %%
# Exiba a média de valores dos imóveis da cidade "Belo Horizonte".
# Aqui eu criei apenas com uma variável 
# No notebook vou criar sem variável 


media_valor_BH = df[df["cidade"] == "Belo Horizonte"]

media_valor_BH = df[df["cidade"] == "Belo Horizonte"]["valor"].mean()

media_valor_BH
# Out:
# np.float64(771758.3892617449)

# %%
# Exiba a média de valores dos imóveis da cidade "Belo Horizonte".
# Aqui eu criei apenas com uma variável 
# No notebook vou criar sem variável 
# ou assim 


media_valor_BH = df[df["cidade"] == "Belo Horizonte"]

media_valor_BH = media_valor_BH["valor"].mean()

media_valor_BH
# Out:
# np.float64(771758.3892617449)

# %%
# Exiba a média de valores dos imóveis da cidade "Belo Horizonte".
# Exiba a média de valores dos imóveis da cidade "Belo Horizonte".
# Aqui eu criei sem nenhuma variável 
# aqui eu não separei por & porque só tem um filtro 
# o que caracteriza um filtro é ter uma comparação (==, >=, <=, >, <, !=)

df[df["cidade"]=="Belo Horizonte"]["valor"].mean()
# Out:
# np.float64(771758.3892617449)

# %%
# Exiba os imóveis com valor entre 300000 e 600000 da cidade Curitiba.
# sem variável 
# Conforme aprendi  o () chama a função e o [] acessa uma coluna e filtra dados também . Só que aqui  achamos mais uma função para () que seria separar as condições e isso é comum
# quando tem o & no script. 
# aqui eu  usei   & porque tem mais de um filtro.
# # o que caracteriza um filtro é ter uma comparação (==, >=, <=, >, <, !=) 

df[(df["cidade"] == "Curitiba") & (df["valor"] >= 300000) & (df["valor"] <= 600000)]
# Out:
#                   logradouro tipo_logradouro                 bairro    cidade  \
# 252              das Acacias             Rua          Alto Capivari  Curitiba
# 253             Campo Sereno             Rua          Alto Capivari  Curitiba
# 256     Helena Sampaio Oeste        Travessa          Alto Capivari  Curitiba
# 257            das Figueiras           Viela          Alto Capivari  Curitiba
# 260   dos Jacarandas Central         Avenida          Alto Capivari  Curitiba
# 264           Augusto Ferraz             Rua          Alto Capivari  Curitiba
# 269         Porto das Flores         Avenida  Bairro das Industrias  Curitiba
# 273  Doutor Silveira Central             Rua  Bairro das Industrias  Curitiba
# 277      das Palmeiras Norte             Rua  Bairro das Industrias  Curitiba
# 282         Comendador Prado           Praca       Campo Alegre Sul  Curitiba
# 283        Professor Almeida             Rua       Campo Alegre Sul  Curitiba
# ...

# %%
# Exiba os imóveis com valor entre 300000 e 600000 da cidade Curitiba.
# aqui eu consegui fazer criando uma variável 

df_curitiba = df[df["cidade"] == "Curitiba"]

df_curitiba = df_curitiba[(df_curitiba["valor"] >= 300000) & (df_curitiba["valor"] <= 600000)]

df_curitiba
# Out:
#                   logradouro tipo_logradouro                 bairro    cidade  \
# 252              das Acacias             Rua          Alto Capivari  Curitiba
# 253             Campo Sereno             Rua          Alto Capivari  Curitiba
# 256     Helena Sampaio Oeste        Travessa          Alto Capivari  Curitiba
# 257            das Figueiras           Viela          Alto Capivari  Curitiba
# 260   dos Jacarandas Central         Avenida          Alto Capivari  Curitiba
# 264           Augusto Ferraz             Rua          Alto Capivari  Curitiba
# 269         Porto das Flores         Avenida  Bairro das Industrias  Curitiba
# 273  Doutor Silveira Central             Rua  Bairro das Industrias  Curitiba
# 277      das Palmeiras Norte             Rua  Bairro das Industrias  Curitiba
# 282         Comendador Prado           Praca       Campo Alegre Sul  Curitiba
# 283        Professor Almeida             Rua       Campo Alegre Sul  Curitiba
# ...

# %%
#  Exiba os imóveis com data de aquisição posterior a 2020-01-01.

df_data_especifica = df[df["data_aquisicao"] > "2020-01-01"]

df_data_especifica
# Out:
#            logradouro tipo_logradouro            bairro          cidade  \
# 5     Sao Vicente Sul         Avenida  Alto da Pedreira  Belo Horizonte
# 6      Morro Azul Sul             Rua  Alto da Pedreira  Belo Horizonte
# 7     Veredas do Lago         Estrada  Alto da Pedreira  Belo Horizonte
# 8       Flor do Campo             Rua  Alto da Pedreira  Belo Horizonte
# 9      Helena Sampaio         Alameda  Alto da Pedreira  Belo Horizonte
# ...               ...             ...               ...             ...
# 1495  Veredas do Lago             Rua    Vila Primavera       Sao Paulo
# 1496         dos Ipes         Estrada    Vila Primavera       Sao Paulo
# 1497  Benedito Campos             Rua    Vila Primavera       Sao Paulo
# 1498       Joao Marin             Rua    Vila Primavera       Sao Paulo
# 1499      Monte Claro        Travessa    Vila Primavera       Sao Paulo
#
#            cep         tipo      valor data_aquisicao
# ...

# %%
#  Exiba os imóveis com data de aquisição posterior a 2020-01-01.
# Ou de uma forma mais simples sem variáveis , e aqui mostra que em alguns casos eu tenho que usar variável
# e em outras não .
#  Exiba os imóveis com data de aquisição posterior a 2020-01-01.

df[df["data_aquisicao"] > "2020-01-01"]
# Out:
#            logradouro tipo_logradouro            bairro          cidade  \
# 5     Sao Vicente Sul         Avenida  Alto da Pedreira  Belo Horizonte
# 6      Morro Azul Sul             Rua  Alto da Pedreira  Belo Horizonte
# 7     Veredas do Lago         Estrada  Alto da Pedreira  Belo Horizonte
# 8       Flor do Campo             Rua  Alto da Pedreira  Belo Horizonte
# 9      Helena Sampaio         Alameda  Alto da Pedreira  Belo Horizonte
# ...               ...             ...               ...             ...
# 1495  Veredas do Lago             Rua    Vila Primavera       Sao Paulo
# 1496         dos Ipes         Estrada    Vila Primavera       Sao Paulo
# 1497  Benedito Campos             Rua    Vila Primavera       Sao Paulo
# 1498       Joao Marin             Rua    Vila Primavera       Sao Paulo
# 1499      Monte Claro        Travessa    Vila Primavera       Sao Paulo
#
#            cep         tipo      valor data_aquisicao
# ...

# %%
#Exiba os imóveis que não sejam do tipo "apartamento" e tenham valor menor ou igual a 600000.
# aqui fiz sem variáveis . 

df[(df["tipo"] != "Apartamento") & (df["valor"] <= 600000)]
# Out:
#                   logradouro tipo_logradouro                 bairro  \
# 2     Canario Branco Central             Rua       Alto da Pedreira
# 5            Sao Vicente Sul         Avenida       Alto da Pedreira
# 7            Veredas do Lago         Estrada       Alto da Pedreira
# 15               Laranjeiras         Avenida  Jardim Horizonte Azul
# 16                  dos Ipes         Avenida  Jardim Horizonte Azul
# ...                      ...             ...                    ...
# 1436           Flor do Campo         Avenida         Vila Horizonte
# 1481    Ribeirao Claro Norte             Rua         Vila Primavera
# 1486        Porto das Flores         Avenida         Vila Primavera
# 1489         Capitao Noronha             Rua         Vila Primavera
# 1499             Monte Claro        Travessa         Vila Primavera
#
#               cidade       cep            tipo     valor data_aquisicao
# 2     Belo Horizonte  31093672          Kitnet  247000.0     2017-05-11
# ...

# %%
#Exiba os imóveis que não sejam do tipo "apartamento" e tenham valor menor ou igual a 600000.
# Já nesse criei uma variável . 

df_filtrado = df[(df["tipo"] != "Apartamento") & (df["valor"] <= 600000)]

df_filtrado
# Out:
#                   logradouro tipo_logradouro                 bairro  \
# 2     Canario Branco Central             Rua       Alto da Pedreira
# 5            Sao Vicente Sul         Avenida       Alto da Pedreira
# 7            Veredas do Lago         Estrada       Alto da Pedreira
# 15               Laranjeiras         Avenida  Jardim Horizonte Azul
# 16                  dos Ipes         Avenida  Jardim Horizonte Azul
# ...                      ...             ...                    ...
# 1436           Flor do Campo         Avenida         Vila Horizonte
# 1481    Ribeirao Claro Norte             Rua         Vila Primavera
# 1486        Porto das Flores         Avenida         Vila Primavera
# 1489         Capitao Noronha             Rua         Vila Primavera
# 1499             Monte Claro        Travessa         Vila Primavera
#
#               cidade       cep            tipo     valor data_aquisicao
# 2     Belo Horizonte  31093672          Kitnet  247000.0     2017-05-11
# ...

# %%
# Exiba os imóveis da cidade "Curitiba" cujo bairro não seja "Residencial Tingui".
# aqui fiz  sem variável . 

df[(df["cidade"] == "Curitiba") & (df["bairro"] != "Residencial Tingui")]
# Out:
#                logradouro tipo_logradouro          bairro    cidade       cep  \
# 250      Vale Verde Oeste         Alameda   Alto Capivari  Curitiba  82120169
# 251         Padre Avelino         Avenida   Alto Capivari  Curitiba  82754280
# 252           das Acacias             Rua   Alto Capivari  Curitiba  80251237
# 253          Campo Sereno             Rua   Alto Capivari  Curitiba  82695448
# 254         Quinta do Sol             Rua   Alto Capivari  Curitiba  80387186
# ..                    ...             ...             ...       ...       ...
# 360          Serra Bonita         Alameda  Vila Pinheiros  Curitiba  81457564
# 361        Canario Branco             Rua  Vila Pinheiros  Curitiba  80817291
# 362       Olivia Monteiro         Rodovia  Vila Pinheiros  Curitiba  80192125
# 363  Ribeirao Claro Oeste         Avenida  Vila Pinheiros  Curitiba  81222033
# 364    Engenheiro Tavares             Rua  Vila Pinheiros  Curitiba  82433117
#
# ...

# %%
# Exiba os imóveis da cidade "Curitiba" cujo bairro não seja "Residencial Tingui".
# aqui fiz com variável. 

df_filtrado = df[(df["cidade"] == "Curitiba") & (df["bairro"] != "Residencial Tingui")]

df_filtrado
# Out:
#                logradouro tipo_logradouro          bairro    cidade       cep  \
# 250      Vale Verde Oeste         Alameda   Alto Capivari  Curitiba  82120169
# 251         Padre Avelino         Avenida   Alto Capivari  Curitiba  82754280
# 252           das Acacias             Rua   Alto Capivari  Curitiba  80251237
# 253          Campo Sereno             Rua   Alto Capivari  Curitiba  82695448
# 254         Quinta do Sol             Rua   Alto Capivari  Curitiba  80387186
# ..                    ...             ...             ...       ...       ...
# 360          Serra Bonita         Alameda  Vila Pinheiros  Curitiba  81457564
# 361        Canario Branco             Rua  Vila Pinheiros  Curitiba  80817291
# 362       Olivia Monteiro         Rodovia  Vila Pinheiros  Curitiba  80192125
# 363  Ribeirao Claro Oeste         Avenida  Vila Pinheiros  Curitiba  81222033
# 364    Engenheiro Tavares             Rua  Vila Pinheiros  Curitiba  82433117
#
# ...

# %%
# Exiba os imóveis cujo valor seja maior que a média geral e cuja data de aquisição seja anterior a 2021-01-01.

df_valor_medio =  df["valor"].mean()

df_filtrado = df[(df_valor_medio < df["valor"]) & (df["data_aquisicao"] < "2021-01-01")]

df_filtrado
# Out:
#                  logradouro tipo_logradouro                 bairro  \
# 0             Quinta do Sol             Rua       Alto da Pedreira
# 1          Antonio Loureiro             Rua       Alto da Pedreira
# 3             das Palmeiras         Avenida       Alto da Pedreira
# 4          Antonio Loureiro             Rua       Alto da Pedreira
# 17         Antonio Loureiro             Rua  Jardim Horizonte Azul
# ...                     ...             ...                    ...
# 1480  Flor do Campo Central             Rua         Vila Primavera
# 1482        Veredas do Lago             Rua         Vila Primavera
# 1484   Helena Sampaio Oeste         Avenida         Vila Primavera
# 1487         das Mangueiras           Largo         Vila Primavera
# 1488     Raul Peixoto Norte             Rua         Vila Primavera
#
#               cidade       cep         tipo      valor data_aquisicao
# 0     Belo Horizonte  30840439      Terreno  1192500.0     2015-10-10
# ...

# %%
# esse comando me mostra o tamanho que cada coluna ocupa , por exemplo, o logradouro ocupa 94 mil bytes que é igual 94 kb

df.memory_usage (deep=True)
# Out:
# Index                 132
# logradouro          94765
# tipo_logradouro     80850
# bairro             100437
# cidade              89014
# cep                 12000
# tipo                85015
# valor               12000
# data_aquisicao      12000
# dtype: int64

# %%
# Exiba os imóveis cujo CEP comece com "80" e cujo tipo seja "casa".
# astype transforma a coluna cep em string e precisa transformar para string porque o startswith só 
# funciona com string , para pegar algo que começa com  só string, não da pra fazer com número.
# usei uma variável só , mas  da pra fazer até sem variável 
# lembrando que toda vez antes de usar o startwith  tem que ter .str  antes conforme abaixo. 

df_imovel_especifico = df[(df["cep"].astype(str).str.startswith("80")) & (df["tipo"] == "Casa")]

df_imovel_especifico
# Out:
#               logradouro tipo_logradouro                 bairro    cidade  \
# 254        Quinta do Sol             Rua          Alto Capivari  Curitiba
# 257        das Figueiras           Viela          Alto Capivari  Curitiba
# 268          Laranjeiras         Alameda  Bairro das Industrias  Curitiba
# 270  Flor do Campo Norte         Avenida  Bairro das Industrias  Curitiba
# 276    Alto do Cedro Sul             Rua  Bairro das Industrias  Curitiba
# 294   Augusto Ferraz Sul         Rodovia       Jardim Araucaria  Curitiba
# 295       Canario Branco         Alameda       Jardim Araucaria  Curitiba
# 304         das Violetas             Rua       Jardim Araucaria  Curitiba
# 312          Monte Claro         Rodovia    Jardim das Estacoes  Curitiba
# 323       Clara Nogueira         Avenida    Jardim das Estacoes  Curitiba
# 345   Augusto Ferraz Sul         Alameda       Vila Neve Branca  Curitiba
# 359        das Orquideas             Rua         Vila Pinheiros  Curitiba
# ...

# %%
# Exiba os imóveis cujo CEP comece com "80" e cujo tipo seja "casa".
# astype transforma a coluna cep em string e precisa transformar para string porque o startswith só 
# funciona com string , para pegar algo que começa com  só string, não da pra fazer com número.
# aqui usei duas variáveis 
# lembrando que toda vez antes de usar o startwith  tem que ter .str  antes conforme abaixo. 

df_cep_tratado= df[df["cep"].astype(str).str.startswith("80")]

df_imovel_tratado = df_cep_tratado[df_cep_tratado["tipo"]=="Casa"]

df_imovel_tratado
# Out:
#               logradouro tipo_logradouro                 bairro    cidade  \
# 254        Quinta do Sol             Rua          Alto Capivari  Curitiba
# 257        das Figueiras           Viela          Alto Capivari  Curitiba
# 268          Laranjeiras         Alameda  Bairro das Industrias  Curitiba
# 270  Flor do Campo Norte         Avenida  Bairro das Industrias  Curitiba
# 276    Alto do Cedro Sul             Rua  Bairro das Industrias  Curitiba
# 294   Augusto Ferraz Sul         Rodovia       Jardim Araucaria  Curitiba
# 295       Canario Branco         Alameda       Jardim Araucaria  Curitiba
# 304         das Violetas             Rua       Jardim Araucaria  Curitiba
# 312          Monte Claro         Rodovia    Jardim das Estacoes  Curitiba
# 323       Clara Nogueira         Avenida    Jardim das Estacoes  Curitiba
# 345   Augusto Ferraz Sul         Alameda       Vila Neve Branca  Curitiba
# 359        das Orquideas             Rua         Vila Pinheiros  Curitiba
# ...

# %%
# Exiba o apartamento mais caro da cidade "Belo Horizonte"
# lembrando que o sort_values sempre vem do menor para o maior, caso queira do maior para o menor,
# tem que ser sort_values (nome da coluna de ordenação , ascending=False ) , 
#  , precisa usar o False , ai vem do maior para o menor. 
# do menor para o maior  pode ser df.sort_values("valor", ascending=True)  ou df.sort_values("valor") 

df_imovel_tratado = df[df["cidade"] == "Belo Horizonte"]

df_imovel_tratado = df_imovel_tratado[df_imovel_tratado["tipo"] == "Apartamento"].sort_values("valor", ascending=False)

df_imovel_tratado
# Out:
#                   logradouro tipo_logradouro                    bairro  \
# 43     Olivia Monteiro Norte         Avenida        Jardim Serra Clara
# 11            Clara Nogueira             Rua          Alto da Pedreira
# 142          Veredas do Lago         Avenida      Vila Ouro Preto Nova
# 13                Vale Verde             Rua          Alto da Pedreira
# 69               Laranjeiras         Avenida  Residencial Pampulha Sul
# 42             Alto do Cedro         Estrada        Jardim Serra Clara
# 131          Dona Celina Sul           Praca              Vila Mineira
# 139         das Violetas Sul         Avenida      Vila Ouro Preto Nova
# 64             Boa Esperanca             Rua     Parque das Mangueiras
# 76               Nova Aurora         Avenida  Residencial Pampulha Sul
# 48        Engenheiro Tavares         Avenida     Parque das Mangueiras
# 22               Sao Gabriel         Avenida     Jardim Horizonte Azul
# ...

# %%
# Mostre a quantidade de imóveis cadastrados em cada cidade.
# nesse caso  , o necessário  é usar o size para fazer a contagem Conforme  no próximo exemplo
# se usamos o count  não fica bom porque ele conta todas as colunas . 
# outra coisa , contar linha que é o que ele faz aqui não precisa escolher coluna no size que é o que
# conta. 
# aqui fiz sem variável . 


df.groupby("cidade").size()
# Out:
# cidade
# Belo Horizonte         149
# Campinas               101
# Curitiba               115
# Florianopolis           77
# Fortaleza               91
# Goiania                 64
# Niteroi                 54
# Porto Alegre           109
# Recife                 109
# Ribeirao Preto          64
# Rio de Janeiro         151
# Salvador                94
# Santos                  46
# Sao Jose dos Campos     57
# Sao Paulo              219
# dtype: int64

# %%
# Mostre a quantidade de imóveis cadastrados em cada cidade.
# assim não é legal porque ele mostra todas as colunas  com as mesmas contagens, nesse o melhor é usar o size()
# outra coisa , contar linha que é o que ele faz aqui não precisa escolher coluna no count que é o que
# conta. 
# aqui fiz sem variável . 


df.groupby("cidade").count()
# Out:
#                      logradouro  tipo_logradouro  bairro  cep  tipo  valor  \
# cidade
# Belo Horizonte              149              149     149  149   149    149
# Campinas                    101              101     101  101   101    101
# Curitiba                    115              115     115  115   115    115
# Florianopolis                77               77      77   77    77     77
# Fortaleza                    91               91      91   91    91     91
# Goiania                      64               64      64   64    64     64
# Niteroi                      54               54      54   54    54     54
# Porto Alegre                109              109     109  109   109    109
# Recife                      109              109     109  109   109    109
# Ribeirao Preto               64               64      64   64    64     64
# Rio de Janeiro              151              151     151  151   151    151
# ...

# %%
# Mostre a quantidade de imóveis cadastrados em cada cidade.
# perguntar para o professor Lucas se pode ser assim também ao invés do groupby 
# aqui eu já escolho a coluna,  para contar linhas , por isso o ideal é usar o primeiro exemplo com 
# size  desse exercicio. 
# aqui fiz sem variável . 


df["cidade"].value_counts()
# Out:
# cidade
# Sao Paulo              219
# Rio de Janeiro         151
# Belo Horizonte         149
# Curitiba               115
# Porto Alegre           109
# Recife                 109
# Campinas               101
# Salvador                94
# Fortaleza               91
# Florianopolis           77
# Goiania                 64
# Ribeirao Preto          64
# Sao Jose dos Campos     57
# Niteroi                 54
# Santos                  46
# Name: count, dtype: int64

# %%
# Mostre a soma do valor dos imóveis cadastrados em cada cidade.
# aqui fiz sem variável . 

df.groupby("cidade")["valor"].sum()
# Out:
# cidade
# Belo Horizonte         114992000.0
# Campinas                89861000.0
# Curitiba                94940500.0
# Florianopolis           82485000.0
# Fortaleza               64529000.0
# Goiania                 42200500.0
# Niteroi                 48725500.0
# Porto Alegre            95718000.0
# Recife                  84527500.0
# Ribeirao Preto          39754500.0
# Rio de Janeiro         142747500.0
# Salvador                77605500.0
# Santos                  41715000.0
# Sao Jose dos Campos     47590000.0
# Sao Paulo              249063500.0
# Name: valor, dtype: float64

# %%
# Mostre o valor do imóvel mais caro de cada bairro da cidade 'Curitiba'.
# aqui eu criei uma variável só 


df_imoveis_curitiba = df[df['cidade'] == "Curitiba"]

df_imoveis_curitiba = df_imoveis_curitiba.groupby("bairro")["valor"].max()

df_imoveis_curitiba
# Out:
# bairro
# Alto Capivari            2725000.0
# Bairro das Industrias    1337500.0
# Campo Alegre Sul         3090000.0
# Jardim Araucaria         1900000.0
# Jardim das Estacoes      1385000.0
# Parque Barigui Novo      6570000.0
# Residencial Tingui       1377500.0
# Vila Neve Branca         1227500.0
# Vila Pinheiros           1490000.0
# Name: valor, dtype: float64

# %%
# Mostre o valor do imóvel mais caro de cada bairro da cidade 'Curitiba'.
# aqui virou um DF com uma coluna porque usei o . to_frame()


df_imoveis_curitiba = df[df["cidade"] == "Curitiba"]

df_imoveis_curitiba = df_imoveis_curitiba.groupby("bairro")["valor"].max().to_frame()

df_imoveis_curitiba
# Out:
#                            valor
# bairro
# Alto Capivari          2725000.0
# Bairro das Industrias  1337500.0
# Campo Alegre Sul       3090000.0
# Jardim Araucaria       1900000.0
# Jardim das Estacoes    1385000.0
# Parque Barigui Novo    6570000.0
# Residencial Tingui     1377500.0
# Vila Neve Branca       1227500.0
# Vila Pinheiros         1490000.0

# %%
# Mostre o valor do imóvel mais caro de cada bairro da cidade 'Curitiba'.
# aqui virou um DF com uma coluna porque usei o . to_frame()
#  e aqui ainda usei o .reset_index()  para separa o DF em duas colunas 

df_curitiba = df[df["cidade"]=="Curitiba"]

df_curitiba = df_curitiba.groupby("bairro")["valor"].max().to_frame().reset_index()

df_curitiba
# Out:
#                   bairro      valor
# 0          Alto Capivari  2725000.0
# 1  Bairro das Industrias  1337500.0
# 2       Campo Alegre Sul  3090000.0
# 3       Jardim Araucaria  1900000.0
# 4    Jardim das Estacoes  1385000.0
# 5    Parque Barigui Novo  6570000.0
# 6     Residencial Tingui  1377500.0
# 7       Vila Neve Branca  1227500.0
# 8         Vila Pinheiros  1490000.0

# %%
# O type ele mostra qual é o tipo de uma variável , de um objeto . 
# note que no último  que foi o que eu filtrei no exercicio acima,  ele não é um DF e sim uma serie. 

print(type(df))
print(type(df_curitiba))
print(type(df["valor"]))
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.DataFrame'>
# <class 'pandas.Series'>

# %%
# Mostre o valor do imóvel mais barato de cada bairro da cidade 'Curitiba'.

df_curitiba = df[df["cidade"] == "Curitiba"]

df_curitiba = df_curitiba.groupby("bairro")["valor"].min()

df_curitiba
# Out:
# bairro
# Alto Capivari            222000.0
# Bairro das Industrias    161000.0
# Campo Alegre Sul         188000.0
# Jardim Araucaria         282000.0
# Jardim das Estacoes      231000.0
# Parque Barigui Novo      269000.0
# Residencial Tingui       264000.0
# Vila Neve Branca         311000.0
# Vila Pinheiros           238000.0
# Name: valor, dtype: float64

# %%
# Liste o valor médio dos imóveis de cada tipo.

df_valor_medio = df.groupby("tipo")["valor"].mean()

df_valor_medio
# Out:
# tipo
# Apartamento       5.832792e+05
# Casa              9.135745e+05
# Chacara           1.850179e+06
# Cobertura         1.824802e+06
# Galpao            2.805291e+06
# Kitnet            2.180429e+05
# Loja              8.021122e+05
# Sala Comercial    6.809141e+05
# Sobrado           1.192486e+06
# Terreno           1.013181e+06
# Name: valor, dtype: float64

# %%
# Liste o valor médio dos imóveis de cada tipo.
# nesse caso aparece sem notação cientifica 

df_valor_medio = df.groupby("tipo")["valor"].mean().round()

df_valor_medio
# Out:
# tipo
# Apartamento        583279.0
# Casa               913575.0
# Chacara           1850179.0
# Cobertura         1824802.0
# Galpao            2805291.0
# Kitnet             218043.0
# Loja               802112.0
# Sala Comercial     680914.0
# Sobrado           1192486.0
# Terreno           1013181.0
# Name: valor, dtype: float64

# %%
# Liste o valor médio dos imóveis de cada tipo, apenas para os imóveis da cidade de 'Sao Paulo'.

df_sao_paulo = df[df["cidade"] == "Sao Paulo"]

df_sao_paulo =  df_sao_paulo.groupby("tipo")["valor"].mean().round()

df_sao_paulo
# Out:
# tipo
# Apartamento        801986.0
# Casa              1262198.0
# Chacara           1747500.0
# Cobertura         2200000.0
# Galpao            2662083.0
# Kitnet             269250.0
# Loja              1635000.0
# Sala Comercial    1021692.0
# Sobrado           1588750.0
# Terreno           1235500.0
# Name: valor, dtype: float64

# %%
# Liste o valor médio dos imóveis de cada tipo.
# nesse caso aparece sem notação cientifica 
# o round tira a notação cientifica 


df_valor_medio_sp = df[df["cidade"] == "Sao Paulo"]

df_valor_medio_sp =  df_valor_medio_sp.groupby("tipo")["valor"].mean().round()

df_valor_medio_sp
# Out:
# tipo
# Apartamento        801986.0
# Casa              1262198.0
# Chacara           1747500.0
# Cobertura         2200000.0
# Galpao            2662083.0
# Kitnet             269250.0
# Loja              1635000.0
# Sala Comercial    1021692.0
# Sobrado           1588750.0
# Terreno           1235500.0
# Name: valor, dtype: float64

# %%
# Mostre a soma total dos valores dos imóveis em cada cidade, ordenando do maior para o menor valor total.
# aqui porque eu não tive que colocar  .sort_values("valor" , ascending=False)  ? Porque é uma série, e como é serie  não posso colocar uma coluna dentro do sort_values

df_valormax_cidade = df.groupby("cidade")["valor"].sum().sort_values(ascending = False)

df_valormax_cidade
# Out:
# cidade
# Sao Paulo              249063500.0
# Rio de Janeiro         142747500.0
# Belo Horizonte         114992000.0
# Porto Alegre            95718000.0
# Curitiba                94940500.0
# Campinas                89861000.0
# Recife                  84527500.0
# Florianopolis           82485000.0
# Salvador                77605500.0
# Fortaleza               64529000.0
# Niteroi                 48725500.0
# Sao Jose dos Campos     47590000.0
# Goiania                 42200500.0
# Santos                  41715000.0
# Ribeirao Preto          39754500.0
# Name: valor, dtype: float64

# %%
# Mostre a soma total dos valores dos imóveis em cada cidade, ordenando do maior para o menor valor total.
# sort_values(ascending=False) mostra a ordenação decrescente 
# sort_values  mostra a ordenação crescente 
# aqui ele está usando por debaixo dos panos no Pandas metplotlib uma vez que eu tenho ela instalada o python deixa.
# aqui eu baixei em Excel  para testar ,  a linha do código que baixa em excel  to_excel tem que vir abaixo da linha que cria o cálculo, esse é  um ponto importante.
#  Outra coisa importante é que com esse código o gráfico só é gerado no python, para exportar para o Excel não serve. 
# se eu quiser usar o gráfico de coluna em pé,  é  .plot.bar()  se for coluna deitado é .plot.barh()


df_valormax_cidade = df.groupby("cidade")["valor"].sum().sort_values(ascending=False)

df_valormax_cidade.plot.bar()

df_valormax_cidade.to_excel("resultado.xlsx")

# %%
# Mostre a soma total dos valores dos imóveis em cada cidade, ordenando do maior para o menor valor total 
# aqui ele está usando por debaixo dos panos no Pandas metplot uma vez que eu tenho ela instalada o python deixa.

df_valormax_cidade = df.groupby("cidade")["valor"].sum().sort_values(ascending = False)

df_valormax_cidade.plot.barh()
# Out:
# <Axes: ylabel='cidade'>

# %%
# Mostre a soma total dos valores dos imóveis em cada cidade, ordenando do maior para o menor valor total.
# esse .pie() mostra o gráfico de pizza usando o matplotlib no pandas . 

df_valormax_cidade = df.groupby("cidade")["valor"].sum().sort_values(ascending = False)

df_valormax_cidade.plot.pie()
# Out:
# <Axes: >

# %%
# A imobiliária deseja avaliar o estoque de alto padrão em Porto Alegre. 
# Calcule o valor total dos imóveis de cada tipo, considerando apenas imóveis com valor acima de 900000 adquiridos após 2022.
# note que aqui eu tive que fazer os filtros e depois agrupei ,  se eu não tivesse agrupado ele traria um DF  mas como eu agrupei ele trouxe uma série. 

df_portoalegre_altopadrao = df[(df["cidade"] == "Porto Alegre") & (df["valor"]> 900000) & (df["data_aquisicao"] > "2022-12-31")]

df_portoalegre_altopadrao = df_portoalegre_altopadrao.groupby("tipo")["valor"].sum()

df_portoalegre_altopadrao
# Out:
# tipo
# Casa       9815000.0
# Chacara    2150000.0
# Galpao     1487500.0
# Loja       1560000.0
# Sobrado    1720000.0
# Terreno    4222500.0
# Name: valor, dtype: float64

# %%
# A imobiliária quer avaliar quais tipos de imóveis possuem maior valor financeiro no estoque. 
# Calcule a soma do valor dos imóveis de cada tipo, considerando apenas imóveis adquiridos em 2025 e com valor acima de 1000000. 
# Ordene do maior valor total para o menor.

df_estoque_maior_valor = df[(df["data_aquisicao"] >= "2025-01-01") & (df["data_aquisicao"] <= "2025-12-31") & (df["valor"] > 1000000)]

df_estoque_maior_valor = df_estoque_maior_valor.groupby("tipo")["valor"].sum().sort_values(ascending = False)

df_estoque_maior_valor
# Out:
# tipo
# Casa              25477500.0
# Sobrado           21772500.0
# Cobertura         10200000.0
# Terreno            9442500.0
# Chacara            4425000.0
# Apartamento        3685000.0
# Sala Comercial     2630000.0
# Galpao             2250000.0
# Loja               1307500.0
# Name: valor, dtype: float64

# %%
# Para avaliar oportunidades de revenda em São Paulo, 
# exiba a quantidade de imóveis em cada bairro, considerando apenas apartamentos com valor abaixo de 500000 e adquiridos antes de 2021
# aqui não tem resultado 

df_revenda_sp = df[(df["cidade"]=="Sao Paulo") & (df["tipo"]=="Apartamento") & (df["valor"] < 500000) & (df ["data_aquisicao"] < "2021-01-01")]

df_revenda_sp = df_revenda_sp.groupby("bairro").size()

# %%
# Para identificar os bairros com maior oferta de imóveis acessíveis, mostre a quantidade de imóveis cadastrados em cada bairro, 
# considerando apenas aqueles com valor abaixo de 250000. Exiba somente os bairros que possuem pelo menos 3 imóveis.
# note que aqui eu usei um filtro na série e mesmo assim filtro , não entendi muito bem porque filtro a coluna de contagem e não de nome de bairro mas filtro rs . 


df_maiores_ofertas = df[df["valor"] < 250000]

df_maiores_ofertas = df_maiores_ofertas.groupby("bairro").size()

df_maiores_ofertas = df_maiores_ofertas[df_maiores_ofertas >=3]

df_maiores_ofertas
# Out:
# bairro
# Campo Tejipio              3
# Campo Verde Mar            3
# Campo Verde Oeste          3
# Campo das Videiras         4
# Parque Industrial Norte    3
# Parque das Mangueiras      3
# Vila das Pontes            3
# dtype: int64

# %%
#A imobiliária quer avaliar quais tipos de imóveis possuem maior valor financeiro no estoque. Calcule a soma do valor dos imóveis de cada tipo, 
# considerando apenas imóveis adquiridos em 2025 e com valor acima de R$ 1 Milhão. Ordene do maior valor total para o menor.

df_maior_valor_tipo = df[(df["data_aquisicao"] >= "2025-01-01") & (df["data_aquisicao"] <= "2025-12-31") &  (df["valor"] > 1000000)]

df_maior_valor_tipo = df_maior_valor_tipo.groupby("tipo")["valor"].sum().sort_values(ascending=False)

df_maior_valor_tipo
# Out:
# tipo
# Casa              25477500.0
# Sobrado           21772500.0
# Cobertura         10200000.0
# Terreno            9442500.0
# Chacara            4425000.0
# Apartamento        3685000.0
# Sala Comercial     2630000.0
# Galpao             2250000.0
# Loja               1307500.0
# Name: valor, dtype: float64

# %%
# Para avaliar oportunidades de revenda em São Paulo, exiba a quantidade de imóveis em cada bairro, 
# considerando apenas apartamentos com valor abaixo de 400000 e adquiridos antes de 2021

df_revenda_saopaulo = df[(df["cidade"] == "Sao Paulo")&(df["tipo"] == "Apartamento") & (df["valor"] < 400000) & (df["data_aquisicao"] < "2021-01-01")]

df_revenda_saopaulo = df_revenda_saopaulo.groupby("bairro").size()

df_revenda_saopaulo
# Out:
# bairro
# Jardim Monte Claro    2
# Vila Horizonte        1
# Vila Nova Aurora      3
# Vila Primavera        1
# dtype: int64

# %%
# Para identificar os bairros com maior oferta de imóveis acessíveis, mostre a quantidade de imóveis cadastrados em cada bairro, 
# considerando apenas aqueles com valor abaixo de 250000. Exiba somente os bairros que possuem pelo menos 3 imóveis.

df_imoveis_por_bairros = df[df["valor"] < 250000]

df_imoveis_por_bairros = df_imoveis_por_bairros.groupby("bairro").size()

df_imoveis_por_bairros = df_imoveis_por_bairros[df_imoveis_por_bairros >=3]

df_imoveis_por_bairros
# Out:
# bairro
# Campo Tejipio              3
# Campo Verde Mar            3
# Campo Verde Oeste          3
# Campo das Videiras         4
# Parque Industrial Norte    3
# Parque das Mangueiras      3
# Vila das Pontes            3
# dtype: int64

# %%
# A imobiliária quer saber quais bairros de Belo Horizonte possuem maior volume financeiro em imóveis residenciais. 
# Calcule o valor total dos imóveis de cada bairro, considerando apenas casas, apartamentos e sobrados adquiridos após 2021. (Ordenados do maior valor para o menor)
# repare que aqui eu tenho que usar no filtro  o & e o | que é o or . Tenho que por também entre 2 parentêses para não bagunçara lógica. 

df_bh_bairros_maiores_valores = df[(df["cidade"]== "Belo Horizonte") & ((df["tipo"] == "Casa") | (df["tipo"] == "Apartamento") | (df["tipo"] == "Sobrado")) & (df["data_aquisicao"] > "2021-12-31")]

df_bh_bairros_maiores_valores = df_bh_bairros_maiores_valores.groupby("bairro")["valor"].sum().sort_values(ascending = False)

df_bh_bairros_maiores_valores
# Out:
# bairro
# Santa Leonor                8089000.0
# Jardim Horizonte Azul       5953500.0
# Vila Ouro Preto Nova        4220000.0
# Jardim Serra Clara          3587500.0
# Residencial Pampulha Sul    3430000.0
# Vila Mineira                3140500.0
# Alto da Pedreira            2990500.0
# Parque das Mangueiras       1998500.0
# Vila Esperanca Norte        1992500.0
# Name: valor, dtype: float64

# %%
# Exiba um gráfico de pizza (pie) do valor total dos imóveis por tipo.
# não tem ()  no  plot porque o plot é um acesso a biblioteca matplotlib , o que é a função é o pie.

df_total_tipo = df.groupby("tipo")["valor"].sum()

df_total_tipo.plot.pie()
# Out:
# <Axes: >

# %%
# Exiba um gráfico de barras horizontal (barh) do valor total dos imóveis de cada  bairro da cidade "Sao Paulo".
# note que a soma  sempre vem depois do filtro conforme abaixo. 
#  aqui eu não posso fazer assim df_sp = df[(df["cidade"] == "Sao Paulo") & (df.groupby("bairro")["valor"].sum())]  porque o & só junta dois filtros 
# e não  um f iltro com o groupby.  Se eu quiser  fazer em uma linha só, ficaria assim : 
# df_sp = df[(df["cidade"] == "Sao Paulo")].groupby("bairro")["valor"].sum().sort_values(ascending=False)


df_sp = df[(df["cidade"] == "Sao Paulo")]

df_sp = df_sp.groupby("bairro")["valor"].sum().sort_values(ascending=False)

df_sp.plot.barh()
# Out:
# <Axes: ylabel='bairro'>

# %%
# Mude o tipo da coluna "data_aquisicao" para datetime. Use pd.to_datetime
# dtype('<M8[us]')  esse resultado quer  dizer  que a coluna data_aquissicao  já é data 

df["data_aquisicao"].dtype
# Out:
# dtype('<M8[us]')

# %%
# Mude o tipo da coluna "data_aquisicao" para datetime. Use pd.to_datetime
# criei variável mas poderia fazer direto sem variável também , a depender do que eu quero . 
# e o comando para mudar o tipo da data   para data mesmo caso  não seja é chamar o pandas  com pd    depois  . to_datetime     
#como o datatime  é uma função tem que por entre ()  mas  entre []  pra mostrar a coluna que quero mudar .   ai fica  pd.to_datetime(df["data_aquisicao"])


df_data_alterada = pd.to_datetime(df["data_aquisicao"])

df_data_alterada

#df_data_alterada.dtype
# Out:
# 0      2015-10-10
# 1      2016-12-02
# 2      2017-05-11
# 3      2017-05-17
# 4      2019-04-06
#           ...
# 1495   2024-06-22
# 1496   2024-12-14
# 1497   2025-04-19
# 1498   2025-07-04
# 1499   2025-10-22
# Name: data_aquisicao, Length: 1500, dtype: datetime64[us]

# %%
# Crie as colunas ano e mes. Utilize df.data_aquisicao.dt.year e df.data_aquisicao.dt.month.
# vamos lá , a primeira informação importante aqui é que o dt é um comando que extrai partes de uma data de uma coluna no DF . Ele é como o  astype(str).str.startswith
#  mas ao invés de texto pega a data .  
# outra informação aqui é que o enunciado pede para criar colunas no DF,  logo  a variável que eu crio tem que ser uma variável com o nome das  coluans que quero criar
# entre []  e com ""  conforme abaixo . 
#  esse exericio até da pra fazer sem variável também  mas  não faz sentido  porque provavelmente vou querer guardar essas duas colunas que coloquei . 
# uma coisa que achei estranho é que aqui  eu coloquei duas colunas no DF original ,  não teria que ser um novo DF ? 
# aqui o ano é um número assim como  o mês. 

df["ano"] = df["data_aquisicao"].dt.year
df["mes"]= df["data_aquisicao"].dt.month

df
# Out:
#                   logradouro tipo_logradouro            bairro  \
# 0              Quinta do Sol             Rua  Alto da Pedreira
# 1           Antonio Loureiro             Rua  Alto da Pedreira
# 2     Canario Branco Central             Rua  Alto da Pedreira
# 3              das Palmeiras         Avenida  Alto da Pedreira
# 4           Antonio Loureiro             Rua  Alto da Pedreira
# ...                      ...             ...               ...
# 1495         Veredas do Lago             Rua    Vila Primavera
# 1496                dos Ipes         Estrada    Vila Primavera
# 1497         Benedito Campos             Rua    Vila Primavera
# 1498              Joao Marin             Rua    Vila Primavera
# 1499             Monte Claro        Travessa    Vila Primavera
#
#               cidade       cep       tipo      valor data_aquisicao   ano  mes
# 0     Belo Horizonte  30840439    Terreno  1192500.0     2015-10-10  2015   10
# ...

# %%
# Exiba um gráfico de linhas com a evolução do valor total dos imóveis agrupados por ano.
#  veja que como o exercicio pede o gráfico por linha ,  eu  vou usar a função line() e de novo com o acessador plot. 
# aqui eu não ordenei porque ele já vem ordenado pelo ano  por conta do groupby , o groupby sempre ordena pelo índice.

df_valor_ano = df.groupby("ano")["valor"].sum()

df_valor_ano.plot.line()
# Out:
# <Axes: xlabel='ano'>

# %%
# Exiba um gráfico de barras com a quantidade de imóveis adquiridos em cada ano.

df_qtd_imóveis_ano = df.groupby("ano").size()

df_qtd_imóveis_ano.plot.bar()
# Out:
# <Axes: xlabel='ano'>

# %%
# Faça um gráfico de linhas que mostre a evolução do valor dos imóveis adquiridos no ano de 2020, ao longo dos meses.

imoveis_evolucao_2020 = df[(df["data_aquisicao"] >= "2020-01-01") & (df["data_aquisicao"] <= "2020-12-31")].groupby("mes")["valor"].sum()

imoveis_evolucao_2020.plot.line()
# Out:
# <Axes: xlabel='mes'>

# %%
#  ou 

# Faça um gráfico de linhas que mostre a evolução do valor dos imóveis adquiridos no ano de 2020, ao longo dos meses.
# note que  aqui o ano  é um número e não tem que por entre ""

imoveis_evolucao_2020 = df[df["ano"]== 2020].groupby("mes")["valor"].sum()

imoveis_evolucao_2020.plot.line()
# Out:
# <Axes: xlabel='mes'>

# %%
#Calcule o valor total dos imóveis por ano, considerando apenas casas, apartamentos e sobrados adquiridos. 
# Exiba um gráfico de barras agrupado por ano e tipo de imóvel.
# note que aqui não precisei usar o sort_values  ano  porque no groupby  ele já meio que ordena por ano também .
# note 

total_imoveis_ano = df[(df["tipo"] == "Casa") | (df["tipo"] == "Apartamento") | (df["tipo"] == "Sobrado")]

total_imoveis_ano = total_imoveis_ano.groupby(["ano","tipo"])["valor"].sum().unstack()

total_imoveis_ano

total_imoveis_ano.plot.bar()
# Out:
# <Axes: xlabel='ano'>

# %%
# Exiba em um gráfico a média de valores dos apartamentos da cidade "Belo Horizonte", de cada ano.
# aqui usei o line porque é bom pra ver o comportamento (evolução) da média nos anos . 

valormedio_bh = df[(df["cidade"] == "Belo Horizonte") & (df["tipo"] == "Apartamento")]

valormedio_bh = valormedio_bh.groupby("ano")["valor"].mean()

valormedio_bh.plot.line()
# Out:
# <Axes: xlabel='ano'>
